# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import folium

# %%
#load CSV file - ignore header
df = pd.read_csv('../data/POWER_Point_Monthly_Timeseries_1990_2020_035d6118N_083d4895W_LST_GSMNP.csv',header=None)
#print("Column Names:", data.columns)
#df.head(10)

# %%
#extract lat and lon, pick index 3,0 to get the values - revisit and remove the junk rows
location_row = df.iloc[3,0]
latitude_str = location_row.split('Latitude')[1].split('Longitude')[0].strip()
longitude_str = location_row.split('Longitude')[1].strip()
#convert to float
latitude = float(latitude_str)
longitude = float(longitude_str)

print('Latitude:', latitude)
print('Longitude', longitude)
# Out:
# Latitude: 35.6118
# Longitude -83.4895

# %%
df.head(50)
# Out:
#                                                    0
# 0                                      -BEGIN HEADER-  \
# 1   NASA/POWER CERES/MERRA2 Native Resolution Mont...
# 2   Dates (month/day/year): 01/01/1990 through 12/...
# 3   Location: Latitude  35.6118   Longitude -83.4895
# 4   Elevation from MERRA-2: Average for 0.5 x 0.62...
# 5   The value for missing source data that cannot ...
# 6                                      Parameter(s):
# 7   T2M                 MERRA-2 Temperature at 2 M...
# 8   RH2M                MERRA-2 Relative Humidity ...
# 9   T2M_MAX             MERRA-2 Temperature at 2 M...
# 10  T2M_MIN             MERRA-2 Temperature at 2 M...
# 11  PRECTOTCORR         MERRA-2 Precipitation Corr...
# 12  PRECTOTCORR_SUM     MERRA-2 Precipitation Corr...
# 13                                       -END HEADER-
# 14                                          PARAMETER
# 15                                                T2M
# ...

# %%
# THIS DOESNT WORK YET
#convert celcius to farenheit in the months columns but ignore RH2M
months_columns = ['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']
temperature_parameters = ['T2M', 'T2M_MAX', 'T2M_MIN']

# Iterate over the columns and convert Celsius to Fahrenheit for specific parameters
for column in months_columns:
    parameter = df.at[14, column]  # Get the parameter value from the 'PARAMETER' row
    if parameter in temperature_parameters:
        df[column] = (df[column] * 9/5) + 32

print(type(df))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\cjami\anaconda3\envs\geospatial\lib\site-packages\pandas\core\indexes\base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File c:\Users\cjami\anaconda3\envs\geospatial\lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\cjami\anaconda3\envs\geospatial\lib\site-packages\pandas\_libs\index.pyx:155, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\index_class_helper.pxi:70, in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'JAN'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 8
# ...
